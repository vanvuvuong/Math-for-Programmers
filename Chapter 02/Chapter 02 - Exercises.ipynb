# %%
# %reload_ext autoreload
# %autoreload 2
from vector_drawing import *

# %%
points = [(2, -2), (5, -2)]
draw(
    Points(*points),
    Arrow(points[0]),
    Arrow(points[1], (3,0))
)

# %%
dinosaur_points = [
    (6,4), (3,1), (1,2), (-1, 5), (-2, 5), (-3, 4), (-4, 4),
    (-5, 3), (-5, 2), (-2, 2), (-5, 1), (-4, 0), (-2, 1),
    (-1,0), (0, -3), (-1, -4), (1, -4), (2, -3), (1, -2),
    (3,-1), (5, 1)
]
draw(
    Points(*dinosaur_points),
    Polygon(*dinosaur_points)
)
